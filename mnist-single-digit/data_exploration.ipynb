# %% [markdown]
# Data Exploration

# %%
import importlib, data, util
importlib.reload(data)
importlib.reload(util)

# %%
split = "train"
only_digit = 5
cache_dir = "../data/hf_cache"

mnist_dataset = data.HF_MNIST(split=split, only_digit=only_digit, cache_dir=cache_dir)

# %%
batch_size = 20
num_workers = 1
mnist_loader, total_images = data.make_mnist_loader(mnist_dataset=mnist_dataset, batch_size=batch_size, num_workers=num_workers)
print("Total images", total_images)

# %%
images, labels = next(iter(mnist_loader))
util.show_samples_inline(util.make_image_grid(images), title="MNIST images")
